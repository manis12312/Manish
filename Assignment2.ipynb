# %%
for i in range(1,6):
  for j in range(1,i+1):
    print("*",end="")
  print()  
for i in range(4,0,-1):
  for j in range(0,i):
    print("*",end="")
  print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
str=input('Enter the String')
print(str[::-1])
# Out:
# Enter the Stringmanish
# hsinam
