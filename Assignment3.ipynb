# %%
def my_reduce(func,seq1):
  x = seq1[0]
  for i in range(0,len(seq1)):
      x = func(x,seq1[i])         
      return x

my_reduce(lambda a,b: a+b,[1,2,3])
# Out:
# 2

# %%
def my_fliter(func,seq1):
  for i in range(0,len(seq1)):
    x=func(x,seq1[i])
    return True
  return False
    

  my_filter(lambda x:x%2==0,[1,2,3,4,5,6,7,8])

# %%
filter(lambda x:x%2==0,[1,2,3,4,5,56,45])

# %%
str=['x','y','z']
[[j*i] for i in range(1,5)for j in ['x','y','z']]]
# Out:
# [['x'],
#  ['y'],
#  ['z'],
#  ['xx'],
#  ['yy'],
#  ['zz'],
#  ['xxx'],
#  ['yyy'],
#  ['zzz'],
#  ['xxxx'],
#  ['yyyy'],
#  ['zzzz']]

# %%
[i*j for i in ['x','y','z'] for j in range(1,5)]
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %%
[[i+j]for i in [0,1,2] for j in range(2,5)]
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]

# %%
[[j+i for i in [0,1,2,3] ]for j in range(2,8)]
# Out:
# [[2, 3, 4, 5],
#  [3, 4, 5, 6],
#  [4, 5, 6, 7],
#  [5, 6, 7, 8],
#  [6, 7, 8, 9],
#  [7, 8, 9, 10]]

# %%
[(j,i) for i in [1,2,3] for j in range(1,4)]
# Out:
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]
